# %%
# how to remove duplicate elemets
l=[9,0,67,0,8,8]
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s=[89,90,6,'p',788888,45559,6]
s[0]
# Out:
# 89

# %%
s=[89,90,6,'p',788888,45559,6]
s
# Out:
# [89, 90, 6, 'p', 788888, 45559, 6]

# %%
s={9,9,0}
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.update([7,3,5,])
s
# Out:
# {0, 3, 5, 7, 9}

# %%
s={9,9,0}
s.add((8,9,0))
s
# Out:
# {(8, 9, 0), 0, 9}

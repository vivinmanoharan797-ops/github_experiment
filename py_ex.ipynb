# %%
# how to remove duplicate elemets
l=[9,0,67,0,8,8]
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s=[89,90,6,'p',788888,45559,6]
s[0]
# Out:
# 89

# %%
s=[89,90,6,'p',788888,45559,6]
s
# Out:
# [89, 90, 6, 'p', 788888, 45559, 6]

# %%
s={9,9,0}
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.update([7,3,5,])
s
# Out:
# {0, 3, 5, 7, 9}

# %%
s={9,9,0}
s.add((8,9,0))
s
# Out:
# {(8, 9, 0), 0, 9}

# %%
# i want to delete value
s={5,8,9}
s.remove(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}
s.discard(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}
s.discard(80)
s
# Out:
# {5, 8, 9}

# %%
s={5,8,9}
s.remove(80)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 s={5,8,9}
# ----> 2 s.remove(80)
#       3 s
#
# KeyError: 80

# %%
s={7,80,6,9}
s.pop()
s
# Out:
# {6, 7, 9}

# %%
l=[7,9,80,98]
l.pop(0)
l
# Out:
# [9, 80, 98]
